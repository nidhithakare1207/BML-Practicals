# %% [markdown]
# <a href="https://colab.research.google.com/github/nidhithakare1207/BML/blob/main/Experiment_No_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Experiment 02: Apply data preprocessing techniques to make data suitable for machine learning

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from google.colab import files
from google.colab import files

# %%
uploaded = files.upload()
data = pd.read_csv("Salary_dataset.csv")
# Out:
#      <input type="file" id="files-4bf6937e-cf0d-4586-b6ba-8fce24633dfa" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4bf6937e-cf0d-4586-b6ba-8fce24633dfa">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
print("----- Head of Dataset -----")
print(data.head())
# Out:
# ----- Head of Dataset -----
#    Unnamed: 0  YearsExperience   Salary
# 0           0              1.2  39344.0
# 1           1              1.4  46206.0
# 2           2              1.6  37732.0
# 3           3              2.1  43526.0
# 4           4              2.3  39892.0

# %%
print("\n----- Dataset Info -----")
print(data.info())
# Out:
# ----- Dataset Info -----
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       30 non-null     int64
#  1   YearsExperience  30 non-null     float64
#  2   Salary           30 non-null     float64
# dtypes: float64(2), int64(1)
# memory usage: 852.0 bytes
# None

# %%
print("\n----- Missing Values -----")
print(data.isnull().sum())
# Out:
# ----- Missing Values -----
# Unnamed: 0         0
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
print("\n----- Duplicate Rows -----")
print(data.duplicated().sum())
# Out:
# ----- Duplicate Rows -----
# 0

# %%
if "Unnamed: 0" in data.columns:
    data = data.drop(columns=["Unnamed: 0"])

# %%
plt.figure(figsize=(12,5))

# %%
plt.subplot(1,2,1)
sns.scatterplot(x="YearsExperience", y="Salary", data=data)
plt.title("YearsExperience vs Salary")
# Out:
# Text(0.5, 1.0, 'YearsExperience vs Salary')

# %%
plt.subplot(1,2,2)
sns.histplot(data["Salary"], bins=10, kde=True)
plt.title("Salary Distribution")

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.heatmap(data.corr(), annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()
